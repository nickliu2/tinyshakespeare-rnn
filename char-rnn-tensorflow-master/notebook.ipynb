# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
#read the 3 model csv
three_models = pd.read_csv('model_test.csv')
three_models = three_models.iloc[[4, 9, 14]]

# %%
three_models['model'] = ['rnn', 'ltsm', 'gru']

# %%
three_models = three_models.reset_index(drop = True)

# %%
three_models[['model', 'train_perplexity', 'val_perplexity', 'test_perplexity']]
# Out:
#   model  train_perplexity  val_perplexity  test_perplexity
# 0   rnn          6.454024        8.828843        11.178436
# 1  ltsm          5.534065        8.599582        10.953087
# 2   gru          5.181979        8.269981        10.654682

# %%
#read gridsearch csv
gsdf = pd.read_csv('summary.csv')

# %%
df = gsdf.groupby(['rnn_size', 'num_layers', 'seq_length']).last().drop('e', axis = 1)

# %%
df
# Out:
#                                 train_perplexity  val_perplexity  \
# rnn_size num_layers seq_length
# 128      1          50                  5.472596        8.962099
#                     100                 6.302499        7.842210
#                     200                 7.703589        7.880981
#          2          50                  5.187885        8.502688
#                     100                 5.952316        7.593528
#                     200                 7.444526        7.668280
#          3          50                  5.435380        8.517370
#                     100                 6.109549        7.874937
#                     200                 8.332367        8.199908
# 256      1          50                  4.769774        8.292202
#                     100                 5.250506        7.570779
#                     200                 6.365978        7.304573
#          2          50                  4.513839        9.125466
# ...

# %%
df[df['test_perplexity'] == df['test_perplexity'].min()]
# Out:
#                                 train_perplexity  val_perplexity  \
# rnn_size num_layers seq_length
# 256      3          200                 6.700859        7.101228
#
#                                 test_perplexity
# rnn_size num_layers seq_length
# 256      3          200                9.336392

# %%
df[df['val_perplexity'] == df['val_perplexity'].min()]
# Out:
#                                 train_perplexity  val_perplexity  \
# rnn_size num_layers seq_length
# 256      3          200                 6.700859        7.101228
#
#                                 test_perplexity
# rnn_size num_layers seq_length
# 256      3          200                9.336392

# %%
df.sort_values('train_perplexity')
# Out:
#                                 train_perplexity  val_perplexity  \
# rnn_size num_layers seq_length
# 512      1          50                  4.143897        9.344830
#          2          50                  4.155754       10.161028
# 256      2          50                  4.513839        9.125466
# 512      1          100                 4.586301        8.194713
# 256      3          50                  4.596995        9.279647
#          1          50                  4.769774        8.292202
#          2          100                 5.122672        7.660767
# 512      2          100                 5.125926        9.091753
# 128      2          50                  5.187885        8.502688
# 256      1          100                 5.250506        7.570779
#          3          100                 5.297553        7.702707
# 128      3          50                  5.435380        8.517370
# 512      1          200                 5.462352        7.275302
# ...

# %%
df.sort_values('test_perplexity')
# Out:
#                                 train_perplexity  val_perplexity  \
# rnn_size num_layers seq_length
# 256      3          200                 6.700859        7.101228
#          2          200                 5.973053        7.199223
#          1          200                 6.365978        7.304573
# 512      1          200                 5.462352        7.275302
# 128      1          200                 7.703589        7.880981
#          2          200                 7.444526        7.668280
#                     100                 5.952316        7.593528
# 256      1          100                 5.250506        7.570779
# 512      2          200                 7.192738        7.350900
# 128      3          200                 8.332367        8.199908
# 256      3          100                 5.297553        7.702707
# 128      1          100                 6.302499        7.842210
# 256      2          100                 5.122672        7.660767
# ...

# %%
df.sort_values('val_perplexity')
# Out:
#                                 train_perplexity  val_perplexity  \
# rnn_size num_layers seq_length
# 256      3          200                 6.700859        7.101228
#          2          200                 5.973053        7.199223
# 512      1          200                 5.462352        7.275302
# 256      1          200                 6.365978        7.304573
# 512      2          200                 7.192738        7.350900
# 256      1          100                 5.250506        7.570779
# 128      2          100                 5.952316        7.593528
# 256      2          100                 5.122672        7.660767
# 128      2          200                 7.444526        7.668280
# 256      3          100                 5.297553        7.702707
# 128      1          100                 6.302499        7.842210
# 512      3          100                 9.978938        7.853137
# 128      3          100                 6.109549        7.874937
# ...
